# %%
import pandas as pd

# %%
df = pd.read_json("/Users/nazmulhossain/CSE_6242_final/usa_job_20210101_30k_data.json",lines=True)

# %%
#list(df)

# %%
job_df = df[df.category.isin
            (['Computer-or-internet','Upper-Management-or-consulting','Engineering-or-architecture',
              'Telecommunications', 'Healthcare', 'Banking-or-loans','Accounting-or-finance','Pharmaceutical/bio-tech',
       'Marketing-or-advertising-or-pr','Government-or-military'])]

# %%
job_df
# Out:
#                                 uniq_id            crawl_timestamp  \
# 1      959a7778077259539d88d36a63ee77aa  2021-03-03 10:15:39 +0000
# 2      4ef50bb5d04209cb530865627b7e7b39  2021-02-06 06:11:45 +0000
# 3      0e995706ddd2fd642c7ec384c251449b  2021-03-05 16:15:38 +0000
# 5      52cfab2648e8d238219b64ca9ad97429  2021-01-21 09:11:49 +0000
# 6      df677a84584571297579dd22859c1f0c  2021-02-05 20:26:52 +0000
# ...                                 ...                        ...
# 29951  c3a3ec03bb112f5ac7d4a83ec4a5a665  2021-02-10 17:51:39 +0000
# 29955  5e7780c3d14a26d305bf6a387b1d08fd  2021-02-27 09:54:57 +0000
# 29960  c2aa6805e0e6b2c3ab29a53dd9119884  2021-01-06 10:44:44 +0000
# 29962  f99987fe33252e58762893b854dbd7fc  2021-01-11 10:59:42 +0000
# 29963  125bdb4eef8ddcf53e6040db621ddbf2  2021-01-11 10:37:48 +0000
#
#                                                      url  \
# 1      https://www.indeed.com/viewjob?jk=24bb906c8e8c...
# ...

# %%
job_df['category'].unique()
# Out:
# array(['Computer-or-internet', 'Upper-Management-or-consulting',
#        'Engineering-or-architecture', 'Telecommunications', 'Healthcare',
#        'Banking-or-loans', 'Accounting-or-finance',
#        'Government-or-military', 'Pharmaceutical/bio-tech',
#        'Marketing-or-advertising-or-pr'], dtype=object)

# %%
job_df_2 = job_df[job_df['job_title'].str.contains("Engineer|analyst", case=False)]

# %%
job_df_2.to_csv("job_filtered_2.csv")
